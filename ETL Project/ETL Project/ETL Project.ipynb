# %%
import pandas as pd

# %%
foodgroup_file = "food_groups.csv"

# %%
nutritional_file = 'nutritional_info.csv'

# %%
foodgroup_data_df = pd.read_csv(foodgroup_file)
foodgroup_data_df.head()
# Out:
#      ID               FoodGroup              ShortDescrip  \
# 0  1001  Dairy and Egg Products          BUTTER,WITH SALT
# 1  1002  Dairy and Egg Products  BUTTER,WHIPPED,WITH SALT
# 2  1003  Dairy and Egg Products      BUTTER OIL,ANHYDROUS
# 3  1004  Dairy and Egg Products               CHEESE,BLUE
# 4  1005  Dairy and Egg Products              CHEESE,BRICK
#
#                       Descrip CommonName MfgName ScientificName  Energy_kcal  \
# 0              Butter, salted        NaN     NaN            NaN        717.0
# 1  Butter, whipped, with salt        NaN     NaN            NaN        717.0
# 2       Butter oil, anhydrous        NaN     NaN            NaN        876.0
# 3                Cheese, blue        NaN     NaN            NaN        353.0
# 4               Cheese, brick        NaN     NaN            NaN        371.0
#
#    Protein_g  Fat_g  ...  Folate_USRDA  Niacin_USRDA  Riboflavin_USRDA  \
# 0       0.85  81.11  ...        0.0075      0.002625          0.026154
# ...

# %%
nutritional_data_df = pd.read_csv(nutritional_file)
nutritional_data_df.head()
# Out:
#    NDB_No               Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0    1001        BUTTER,WITH SALT      15.87         717         0.85
# 1    1002  BUTTER,WHIPPED,W/ SALT      16.72         718         0.49
# 2    1003    BUTTER OIL,ANHYDROUS       0.24         876         0.28
# 3    1004             CHEESE,BLUE      42.41         353        21.40
# 4    1005            CHEESE,BRICK      41.11         371        23.24
#
#    Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  ...  \
# 0          81.11     2.11            0.06           0.0           0.06  ...
# 1          78.30     1.62            2.87           0.0           0.06  ...
# 2          99.48     0.00            0.00           0.0           0.00  ...
# 3          28.74     5.11            2.34           0.0           0.50  ...
# 4          29.68     3.18            2.79           0.0           0.51  ...
#
#    Vit_K_(µg)  FA_Sat_(g)  FA_Mono_(g)  FA_Poly_(g)  Cholestrl_(mg)  GmWt_1  \
# ...

# %%
new_foodgroup_data_df= foodgroup_data_df[['ID', 'FoodGroup','ShortDescrip', 'Descrip', 'Calcium_mg']].copy()
new_foodgroup_data_df.head()

food_group
# Out:
#      ID               FoodGroup              ShortDescrip  \
# 0  1001  Dairy and Egg Products          BUTTER,WITH SALT
# 1  1002  Dairy and Egg Products  BUTTER,WHIPPED,WITH SALT
# 2  1003  Dairy and Egg Products      BUTTER OIL,ANHYDROUS
# 3  1004  Dairy and Egg Products               CHEESE,BLUE
# 4  1005  Dairy and Egg Products              CHEESE,BRICK
#
#                       Descrip  Calcium_mg
# 0              Butter, salted        24.0
# 1  Butter, whipped, with salt        24.0
# 2       Butter oil, anhydrous         4.0
# 3                Cheese, blue       528.0
# 4               Cheese, brick       674.0

# %%
new_nutritional_data_df= nutritional_data_df[['NDB_No', 'Shrt_Desc','Water_(g)', 'Energ_Kcal', 'Protein_(g)', 'Lipid_Tot_(g)','Carbohydrt_(g)','Sugar_Tot_(g)','Cholestrl_(mg)' ]].copy()
new_nutritional_data_df.head()
# Out:
#    NDB_No               Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0    1001        BUTTER,WITH SALT      15.87         717         0.85
# 1    1002  BUTTER,WHIPPED,W/ SALT      16.72         718         0.49
# 2    1003    BUTTER OIL,ANHYDROUS       0.24         876         0.28
# 3    1004             CHEESE,BLUE      42.41         353        21.40
# 4    1005            CHEESE,BRICK      41.11         371        23.24
#
#    Lipid_Tot_(g)  Carbohydrt_(g)  Sugar_Tot_(g)  Cholestrl_(mg)
# 0          81.11            0.06           0.06           215.0
# 1          78.30            2.87           0.06           225.0
# 2          99.48            0.00           0.00           256.0
# 3          28.74            2.34           0.50            75.0
# 4          29.68            2.79           0.51            94.0

# %%
new_nutritional_data_df=new_nutritional_data_df.rename(columns= {"NDB_No":"ID", "Shrt_Desc": "ShortDescrip", "Lipid_Tot_(g)" :"Fat_(g)"})

# %%
healthy_foodgroup_data_df =new_foodgroup_data_df[new_foodgroup_data_df['Calcium_mg'] <=1500]
healthy_foodgroup_data_df.head()
# Out:
#      ID               FoodGroup              ShortDescrip  \
# 0  1001  Dairy and Egg Products          BUTTER,WITH SALT
# 1  1002  Dairy and Egg Products  BUTTER,WHIPPED,WITH SALT
# 2  1003  Dairy and Egg Products      BUTTER OIL,ANHYDROUS
# 3  1004  Dairy and Egg Products               CHEESE,BLUE
# 4  1005  Dairy and Egg Products              CHEESE,BRICK
#
#                       Descrip  Calcium_mg
# 0              Butter, salted        24.0
# 1  Butter, whipped, with salt        24.0
# 2       Butter oil, anhydrous         4.0
# 3                Cheese, blue       528.0
# 4               Cheese, brick       674.0

# %%
healthy_nutritional_data_df =new_nutritional_data_df[(new_nutritional_data_df['Water_(g)']<=708) & (new_nutritional_data_df['Energ_Kcal']<=2500) & 
(new_nutritional_data_df['Protein_(g)']<=72) & (new_nutritional_data_df['Fat_(g)']<=77) & (new_nutritional_data_df['Carbohydrt_(g)']<=325) & (new_nutritional_data_df['Sugar_Tot_(g)']<=38) &
(new_nutritional_data_df['Cholestrl_(mg)']<=400)]

# %%
healthy_nutritional_data_df.head()
# Out:
#      ID      ShortDescrip  Water_(g)  Energ_Kcal  Protein_(g)  Fat_(g)  \
# 3  1004       CHEESE,BLUE      42.41         353        21.40    28.74
# 4  1005      CHEESE,BRICK      41.11         371        23.24    29.68
# 5  1006       CHEESE,BRIE      48.42         334        20.75    27.68
# 6  1007  CHEESE,CAMEMBERT      51.80         300        19.80    24.26
# 8  1009    CHEESE,CHEDDAR      37.02         404        22.87    33.31
#
#    Carbohydrt_(g)  Sugar_Tot_(g)  Cholestrl_(mg)
# 3            2.34           0.50            75.0
# 4            2.79           0.51            94.0
# 5            0.45           0.45           100.0
# 6            0.46           0.46            72.0
# 8            3.09           0.48            99.0
